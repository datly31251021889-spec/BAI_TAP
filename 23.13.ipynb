# %% [markdown]
# <a href="https://colab.research.google.com/github/datly31251021889-spec/BAI_TAP/blob/main/23.13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import folium
from folium import plugins
import branca
m = folium.Map(location=[10.76936146722942, 106.67113254281593], zoom_start=13)
school = folium.FeatureGroup('Shool')
hospital = folium.FeatureGroup('Hospital')
mall = folium.FeatureGroup('mall')
khu_vuc_uu_tien=folium.FeatureGroup('Khu vực ưu tiên')

folium.Marker([10.7562744,106.6638299], popup='Trường THPT Hùng Vương', tooltip='More detail').add_to(school)
folium.Marker([10.774690056285678, 106.66598476303824], popup='Bệnh viện Nhân dân 115', tooltip='More detail').add_to(hospital)
folium.Marker([10.772687603949377, 106.65814217237784], popup='Trường Đại học Bách Khoa thành phố Hồ Chí Minh', tooltip='More detail').add_to(school)
folium.Marker([10.776726434833423, 106.68671407755906], popup='Bệnh viện Da liễu thành phố Hồ Chí Minh',tooltip='More detail').add_to(hospital)
folium.Marker([10.77105848033802, 106.67019972366249], popup='Vạn Hạnh mall',tooltip='More detail').add_to(mall)
folium.Marker([10.76936146722942, 106.67113254281593], popup='Bệnh viện Nhi đồng 1',tooltip='More detail').add_to(hospital)
folium.Marker([10.77620165245612, 106.6806813219153], popup='Vincom Plaza 3/2',tooltip='More detail').add_to(mall)
school.add_to(m)
hospital.add_to(m)
mall.add_to(m)
khu_vuc_uu_tien.add_to(m)
folium.LayerControl().add_to(m)
folium.Circle((10.76936146722942, 106.67113254281593),radius=2000,color='blue', fill=True, fill_opacity=0.2, popup='Vùng ưu tiên giao hàng').add_to(khu_vuc_uu_tien)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...
